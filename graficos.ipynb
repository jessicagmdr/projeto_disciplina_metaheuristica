# %%
# !pip install openpyxl

# %%
import pandas as pd

# n=20
conjunto1 = [
    (0.005, 0.6, 5840.948549999979),
    (0.005, 0.7, 5937.34848000001),
    (0.005, 0.8, 5756.1547599999785),
    (0.005, 0.9, 5892.738399999962),
    (0.006, 0.6, 5914.173209999974),
    (0.006, 0.7, 5573.871810000053),
    (0.006, 0.8, 5844.589330000014),
    (0.006, 0.9, 5588.005300000041),
    (0.007, 0.6, 5824.290570000024),
    (0.007, 0.7, 5600.420729999974),
    (0.007, 0.8, 5504.15243),
    (0.007, 0.9, 5820.6532799999995),
    (0.008, 0.6, 5824.290570000024),
    (0.008, 0.7, 5600.420729999974),
    (0.008, 0.8, 5504.15243),
    (0.008, 0.9, 5820.6532799999995),
    (0.009, 0.6, 5936.858860000025),
    (0.009, 0.7, 5476.5124300000125),
    (0.009, 0.8, 5942.977319999993),
    (0.009, 0.9, 5803.274759999994),
    (0.01, 0.6, 5979.620419999992),
    (0.01, 0.7, 5689.284060000022),
    (0.01, 0.8, 5292.615059999984),
    (0.01, 0.9, 5843.241109999962),
    (0.02, 0.6, 5973.304989999987),
    (0.02, 0.7, 5704.313050000007),
    (0.02, 0.8, 5318.036160000009),
    (0.02, 0.9, 5387.875839999952),
    (0.03, 0.6, 5659.619560000021),
    (0.03, 0.7, 5666.693050000029),
    (0.03, 0.8, 5483.028629999946),
    (0.03, 0.9, 5323.528789999973),
    (0.04, 0.6, 5858.914839999962),
    (0.04, 0.7, 5750.146850000072),
    (0.04, 0.8, 5657.613050000041),
    (0.04, 0.9, 5846.420959999986),
    (0.05, 0.6, 5363.345459999939),
    (0.05, 0.7, 4778.611730000051),
    (0.05, 0.8, 5638.995690000059),
    (0.05, 0.9, 5933.57499000005)
]

# n=50
conjunto2 = [
    (0.005, 0.6, 5720.248090000022),
    (0.005, 0.7, 5916.686769999996),
    (0.005, 0.8, 5791.897389999956),
    (0.005, 0.9, 5410.393289999993),
    (0.006, 0.6, 5880.641499999956),
    (0.006, 0.7, 5801.305370000013),
    (0.006, 0.8, 5811.409560000067),
    (0.006, 0.9, 5131.124379999978),
    (0.007, 0.6, 5863.048940000012),
    (0.007, 0.7, 5972.416540000002),
    (0.007, 0.8, 5682.204290000023),
    (0.007, 0.9, 5975.933669999987),
    (0.008, 0.6, 5863.048940000012),
    (0.008, 0.7, 5972.416540000002),
    (0.008, 0.8, 5682.204290000023),
    (0.008, 0.9, 5975.933669999987),
    (0.009, 0.6, 5562.438479999982),
    (0.009, 0.7, 5998.458400000003),
    (0.009, 0.8, 5507.2605700000095),
    (0.009, 0.9, 5724.302670000001),
    (0.01, 0.6, 5804.661119999975),
    (0.01, 0.7, 5634.785539999999),
    (0.01, 0.8, 5824.25110999999),
    (0.01, 0.9, 5812.343910000012),
    (0.02, 0.6, 5919.0411099999965),
    (0.02, 0.7, 5825.675529999996),
df_conjunto1 = pd.DataFrame(conjunto1, columns=["Taxa de Mutação", "Taxa de Cruzamento", "Resultado"])
df_conjunto2 = pd.DataFrame(conjunto2, columns=["Taxa de Mutação", "Taxa de Cruzamento", "Resultado"])
df_conjunto3 = pd.DataFrame(conjunto3, columns=["Taxa de Mutação", "Taxa de Cruzamento", "Resultado"])
df_conjunto4 = pd.DataFrame(conjunto4, columns=["Taxa de Mutação", "Taxa de Cruzamento", "Resultado"])
df_conjunto5 = pd.DataFrame(conjunto5, columns=["Taxa de Mutação", "Taxa de Cruzamento", "Resultado"])

# Concatenar os DataFrames lado a lado
df_final = pd.concat([df_conjunto1, df_conjunto2, df_conjunto3, df_conjunto4,df_conjunto5], axis=1)

# Exportar para Excel
df_final.to_excel("dados.xlsx", index=False)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Carregar os dados do arquivo Excel
df = pd.read_excel('dados_agrupados.xlsx')

# Dividir os dados em quatro conjuntos separados
conjunto1 = df.iloc[:, :3]
conjunto2 = df.iloc[:, 3:6]
conjunto3 = df.iloc[:, 6:9]
conjunto4 = df.iloc[:, 9:12]
conjunto5 = df.iloc[:, 12:15]

# Criar os subplots
fig, axs = plt.subplots(2, 3, figsize=(10, 8))

# Plotar o primeiro conjunto de dados
axs[0, 0].bar(range(len(conjunto1)), conjunto1.iloc[:, 2])
axs[0, 0].set_xlabel('Taxa de Mutação')
axs[0, 0].set_ylabel('Resultado')

# Plotar o segundo conjunto de dados
axs[0, 1].bar(range(len(conjunto2)), conjunto2.iloc[:, 2])
axs[0, 1].set_xlabel('Taxa de Mutação')
axs[0, 1].set_ylabel('Resultado')

# Plotar o terceiro conjunto de dados
axs[1, 0].bar(range(len(conjunto3)), conjunto3.iloc[:, 2])
axs[1, 0].set_xlabel('Taxa de Mutação')
axs[1, 0].set_ylabel('Resultado')

# Plotar o quarto conjunto de dados
axs[1, 1].bar(range(len(conjunto4)), conjunto4.iloc[:, 2])
axs[1, 1].set_xlabel('Taxa de Mutação')
axs[1, 1].set_ylabel('Resultado')

# Plotar o quarto conjunto de dados
axs[1, 1].bar(range(len(conjunto5)), conjunto5.iloc[:, 2])
axs[1, 1].set_xlabel('Taxa de Mutação')
axs[1, 1].set_ylabel('Resultado')

# Ajustar a posição dos subplots
plt.tight_layout()

# Exibir o gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 38
#      35 axs[1, 1].set_ylabel('Resultado')
#      37 # Plotar o quarto conjunto de dados
# ---> 38 axs[1, 1].bar(range(len(conjunto5)), conjunto5.iloc[:, 2])
#      39 axs[1, 1].set_xlabel('Taxa de Mutação')
#      40 axs[1, 1].set_ylabel('Resultado')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Carregar os dados do arquivo Excel
df = pd.read_excel('dados.xlsx')

# Dividir os dados em quatro conjuntos separados
conjunto1 = df.iloc[:, :3]
conjunto2 = df.iloc[:, 3:6]
conjunto3 = df.iloc[:, 6:9]
conjunto4 = df.iloc[:, 9:12]
conjunto5 = df.iloc[:, 12:15]

# Criar os subplots
fig, axs = plt.subplots(3, 2, figsize=(20, 12))

# Plotar o primeiro conjunto de dados
bars1 = axs[0, 0].bar(range(len(conjunto1)), conjunto1.iloc[:, 2])
axs[0, 0].set_xlabel('Taxa de Mutação')
axs[0, 0].set_ylabel('Resultado')
min_bar1 = min(bars1, key=lambda bar: bar.get_height())
min_bar1.set_color('red')
axs[0, 0].legend([f'Menor Barra: {min_bar1.get_height()}'])

# Adicionar rótulos numerados ao eixo x
axs[0, 0].set_xticks(range(len(conjunto1)))
axs[0, 0].set_xticklabels(range(1, len(conjunto1) + 1))

# Plotar o segundo conjunto de dados
bars2 = axs[0, 1].bar(range(len(conjunto2)), conjunto2.iloc[:, 2])
axs[0, 1].set_xlabel('Taxa de Mutação')
axs[0, 1].set_ylabel('Resultado')
min_bar2 = min(bars2, key=lambda bar: bar.get_height())
min_bar2.set_color('red')
axs[0, 1].legend([f'Menor Barra: {min_bar2.get_height()}'])

# Adicionar rótulos numerados ao eixo x
axs[0, 1].set_xticks(range(len(conjunto2)))
axs[0, 1].set_xticklabels(range(1, len(conjunto2) + 1))

# Plotar o terceiro conjunto de dados
bars3 = axs[1, 0].bar(range(len(conjunto3)), conjunto3.iloc[:, 2])
axs[1, 0].set_xlabel('Taxa de Mutação')
axs[1, 0].set_ylabel('Resultado')
min_bar3 = min(bars3, key=lambda bar: bar.get_height())
min_bar3.set_color('red')
axs[1, 0].legend([f'Menor Barra: {min_bar3.get_height()}'])

# Adicionar rótulos numerados ao eixo x
axs[1, 0].set_xticks(range(len(conjunto3)))
axs[1, 0].set_xticklabels(range(1, len(conjunto3) + 1))

# Plotar o quarto conjunto de dados
bars4 = axs[1, 1].bar(range(len(conjunto4)), conjunto4.iloc[:, 2])
axs[1, 1].set_xlabel('Taxa de Mutação')
axs[1, 1].set_ylabel('Resultado')
min_bar4 = min(bars4, key=lambda bar: bar.get_height())
min_bar4.set_color('red')
axs[1, 1].legend([f'Menor Barra: {min_bar4.get_height()}'])

# Adicionar rótulos numerados ao eixo x
axs[1, 1].set_xticks(range(len(conjunto4)))
axs[1, 1].set_xticklabels(range(1, len(conjunto4) + 1))

# Plotar o quinto conjunto de dados
bars5 = axs[2, 0].bar(range(len(conjunto5)), conjunto5.iloc[:, 2])
axs[2, 0].set_xlabel('Taxa de Mutação')
axs[2, 0].set_ylabel('Resultado')
min_bar5 = min(bars5, key=lambda bar: bar.get_height())
min_bar5.set_color('red')
axs[2, 0].legend([f'Menor Barra: {min_bar5.get_height()}'])

# Adicionar rótulos numerados ao eixo x
axs[2, 0].set_xticks(range(len(conjunto5)))
axs[2, 0].set_xticklabels(range(1, len(conjunto5) + 1))

# Ajustar a posição dos subplots
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %% [markdown]
# n=20
# 38: 0.05	0.70	4,778.61
# n=50
# 27: 0.02	0.80	4,785.87
# n=100
# 39: 0.05	0.80	5,097.91
# n=150***
# 25: 0.02	0.60	4,728.27
# n=200
# 8: 0.01	0.90	4,933.38
